# %%
import matplotlib.pyplot as plt
import random
d=[random.randint(1,30) for _ in range (400)]
d
# Out:
# [24,
#  13,
#  10,
#  9,
#  3,
#  23,
#  15,
#  4,
#  19,
#  16,
#  3,
#  2,
#  30,
#  19,
#  18,
#  17,
#  7,
#  30,
#  23,
#  10,
#  23,
#  21,
#  14,
#  11,
#  25,
#  13,
#  2,
#  22,
#  4,
#  8,
#  7,
#  13,
#  17,
#  11,
#  2,
#  17,
#  21,
#  19,
#  21,
#  20,
#  6,
#  15,
#  17,
#  12,
#  30,
#  4,
#  24,
#  25,
#  9,
#  29,
#  16,
#  1,
#  19,
#  2,
#  25,
#  1,
#  28,
#  5,
#  5,
#  6,
#  12,
#  1,
#  13,
#  19,
#  30,
#  18,
#  2,
#  30,
#  20,
#  10,
#  9,
#  15,
#  27,
#  20,
#  26,
#  25,
#  8,
#  27,
#  5,
#  26,
#  4,
#  9,
#  28,
#  28,
#  29,
#  2,
#  13,
#  30,
#  20,
#  4,
#  10,
#  10,
#  11,
#  12,
#  17,
#  3,
#  3,
#  29,
#  22,
#  11,
#  12,
#  9,
#  2,
#  14,
#  10,
#  26,
#  24,
#  12,
#  14,
#  7,
#  21,
#  26,
#  27,
#  18,
#  14,
#  3,
#  6,
#  13,
#  5,
#  4,
#  2,
#  12,
#  6,
#  27,
#  17,
#  24,
#  11,
#  19,
#  8,
#  12,
#  28,
#  3,
#  19,
#  16,
#  16,
#  29,
#  7,
#  25,
#  2,
#  5,
#  16,
#  1,
#  9,
#  25,
#  7,
#  22,
#  28,
#  28,
#  22,
#  17,
#  16,
#  18,
#  21,
#  23,
#  17,
#  28,
#  11,
#  6,
#  14,
#  13,
#  5,
#  20,
#  7,
#  21,
#  23,
#  5,
#  23,
#  15,
#  1,
#  15,
#  13,
#  2,
#  29,
#  23,
#  15,
#  1,
#  30,
#  11,
#  8,
#  29,
#  16,
#  16,
#  6,
#  6,
#  21,
#  16,
#  28,
#  8,
#  28,
#  23,
#  23,
#  5,
#  26,
#  16,
#  24,
#  29,
#  30,
#  15,
#  20,
#  3,
#  14,
#  6,
#  15,
#  23,
#  28,
#  28,
#  15,
#  25,
#  17,
#  21,
#  24,
#  27,
#  6,
#  15,
#  16,
#  19,
#  3,
#  8,
#  14,
#  4,
#  1,
#  22,
#  20,
#  16,
#  29,
#  17,
#  6,
#  4,
#  3,
#  28,
#  27,
#  20,
#  21,
#  19,
#  3,
#  10,
#  2,
#  16,
#  20,
#  6,
#  1,
#  22,
#  18,
#  17,
#  6,
#  27,
#  6,
#  1,
#  4,
#  17,
#  28,
#  11,
#  3,
#  23,
#  10,
#  30,
#  16,
#  17,
#  29,
#  16,
#  13,
#  17,
#  8,
#  19,
#  17,
#  9,
#  6,
#  22,
#  29,
#  5,
#  23,
#  25,
#  14,
#  21,
#  15,
#  7,
#  17,
#  7,
#  6,
#  22,
#  17,
#  4,
#  20,
#  25,
#  1,
#  8,
#  11,
#  14,
#  26,
#  27,
#  23,
#  16,
#  20,
#  7,
#  8,
#  19,
#  8,
#  21,
#  13,
#  4,
#  27,
#  21,
#  27,
#  12,
#  9,
#  3,
#  13,
#  15,
#  15,
#  28,
#  6,
#  16,
#  30,
#  7,
#  12,
#  18,
#  17,
#  11,
#  10,
#  22,
#  16,
#  8,
#  25,
#  30,
#  30,
#  22,
#  15,
#  30,
#  2,
#  7,
#  17,
#  25,
#  12,
#  28,
#  9,
#  30,
#  22,
#  26,
#  4,
#  10,
#  28,
#  5,
#  10,
#  12,
#  22,
#  3,
#  24,
#  11,
#  29,
#  21,
#  5,
#  20,
#  9,
#  9,
#  13,
#  2,
#  9,
#  14,
#  18,
#  16,
#  20,
#  27,
#  2,
#  27,
#  25,
#  27,
#  24,
#  20,
#  15,
#  15,
#  9,
#  28,
#  1,
#  28,
#  19,
#  21,
#  25,
#  10,
#  9,
#  2,
#  15,
#  2,
#  8,
#  16,
#  17,
#  23,
#  29,
#  18,
#  1,
#  1,
#  1,
#  12,
#  28,
#  1,
#  6,
#  9,
#  16,
#  5,
#  15,
#  1]

# %%
plt.hist(d,bins=15)
plt.title("Random value histogram")
plt.show()

# %%
cate = ['Fation ', 'Electronics','Travel','manufacturing']
sale=[200,450,600,1000]
plt.pie(sale,labels = cate , autopct = '%1.1f%%',startangle=60)
plt.title("sector wise sale")
plt.show()
