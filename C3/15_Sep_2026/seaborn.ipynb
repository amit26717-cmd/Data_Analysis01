# %%
 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

penguins = sns.load_dataset("penguins")
penguins = sns.pairplot(penguins,hue= "species")
print(penguins)
plt.show()

# %%
import seaborn as sns
penguins = sns.load_dataset("penguins")
sns.scatterplot(data=penguins, x='bill_length_mm', y='body_mass_g', hue='sex', style='island')
plt.show()

# %%
sns.relplot(data = penguins,x='bill_length_mm',y='body_mass_g',kind='scatter',hue='sex',style='island')

# %%
gap=px.data.gapminder()
print(gap)
temp_df=gap[gap['country']=='India']
print(temp_df)
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
# axes level function 
sns.barplot(data=temp_df,x='year',y='lifeExp',color='g')
plt.show()

# %%
sns.lineplot(data=temp_df,x='year',y='lifeExp',color='g')
plt.show()

# %%
sns.scatterplot(data=temp_df,x='year',y='lifeExp',color='g')
plt.show()

# %%
sns.displot(data=temp_df,x='year',y='lifeExp',color='g')
plt.show()

# %%
sns.catplot(data=temp_df,x='year',y='lifeExp',color='g')
plt.show()

# %%
sns.catplot(data=temp_df,kind ='violin',x='year',y='lifeExp',hue='iso_num',split=True)
plt.show()
