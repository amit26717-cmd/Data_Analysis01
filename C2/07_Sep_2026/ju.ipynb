# %%
import pandas as pd
df = pd.read_csv('t.csv')
print(df.to_string(index=False))    #Without index
df      #With Index
# Out:
#      field_order                                    field_name  \
# 0              1                                        UNITID
# 1              2                                         OPEID
# 2              3                                        OPEID6
# 3              4                                        INSTNM
# 4              5                                         ALIAS
# ..           ...                                           ...
# 169          170               undergraduate_enrollment_status
# 170          171    undergraduate_enrollment_validation_status
# 171          172            undergraduate_enrollment_size_band
# 172          173      undergraduate_enrollment_size_band_order
# 173          174  undergraduate_enrollment_interpretation_note
#
#                                     display_label  \
# 0                                          UNITID
# 1                                           OPEID
# 2                                          OPEID6
# ...
