# %%
import pandas as pd 
df=pd.read_csv('orders.csv')
# df.head()
# df.info()
df.loc[15]
# df.iloc[0,'word_freq_all']
# Out:
# OrderID                  1016
# CustomerName     Ahmed Hassan
# Product         Printer Paper
# Category           Stationery
# Quantity                   20
# Price                     8.0
# OrderDate          2024-06-17
# Shipped                   Yes
# Country                 Egypt
# Name: 15, dtype: object

# %%
import pandas as pd 
df=pd.read_csv('orders.csv')
df.iloc[[0, 2]]
# Out:
#    OrderID CustomerName       Product     Category  Quantity   Price  \
# 0     1001   John Smith        Laptop  Electronics         1  1200.0
# 2     1003     Ali Khan  Office Chair    Furniture         1   300.0
#
#     OrderDate Shipped Country
# 0  01-06-2024     Yes     USA
# 2  04-06-2024     Yes     UAE
